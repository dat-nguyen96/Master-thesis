# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re

# %%
pagesToGet= 100

data = pd.DataFrame([])
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/'+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    links = soup.find_all('li',attrs={"class":"lx-stream__post-container"})
    for i in links:
        try: 
            title = i.find("span",attrs={'class':'lx-stream-post__header-text gs-u-align-middle'}).text.strip()
            link = "https://www.bbc.com"
            link += i.find('a',attrs={"class":"qa-heading-link lx-stream-post__header-link"})["href"]
            date = i.find('div',attrs={"class":"gs-u-display-flex"}).find("span",attrs={"class":"qa-post-auto-meta"}).text
            data = data.append(pd.DataFrame({'title': title, 'url': link,'date' : date}, index=[0]), ignore_index=True)
        except:
            continue
# Out:
# processing page : 1
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/1
# processing page : 2
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/2
# processing page : 3
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/3
# processing page : 4
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/4
# processing page : 5
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/5
# processing page : 6
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/6
# processing page : 7
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/7
# processing page : 8
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/8
# processing page : 9
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/9
# processing page : 10
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/10
# processing page : 11
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/11
# processing page : 12
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/12
# processing page : 13
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/13
# processing page : 14
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/14
# processing page : 15
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/15
# processing page : 16
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/16
# processing page : 17
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/17
# processing page : 18
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/18
# processing page : 19
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/19
# processing page : 20
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/20
# processing page : 21
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/21
# processing page : 22
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/22
# processing page : 23
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/23
# processing page : 24
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/24
# processing page : 25
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/25
# processing page : 26
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/26
# processing page : 27
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/27
# processing page : 28
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/28
# processing page : 29
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/29
# processing page : 30
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/30
# processing page : 31
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/31
# processing page : 32
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/32
# processing page : 33
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/33
# processing page : 34
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/34
# processing page : 35
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/35
# processing page : 36
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/36
# processing page : 37
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/37
# processing page : 38
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/38
# processing page : 39
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/39
# processing page : 40
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/40
# processing page : 41
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/41
# processing page : 42
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/42
# processing page : 43
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/43
# processing page : 44
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/44
# processing page : 45
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/45
# processing page : 46
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/46
# processing page : 47
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/47
# processing page : 48
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/48
# processing page : 49
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/49
# processing page : 50
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/50
# processing page : 51
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/51
# processing page : 52
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/52
# processing page : 53
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/53
# processing page : 54
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/54
# processing page : 55
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/55
# processing page : 56
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/56
# processing page : 57
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/57
# processing page : 58
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/58
# processing page : 59
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/59
# processing page : 60
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/60
# processing page : 61
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/61
# processing page : 62
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/62
# processing page : 63
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/63
# processing page : 64
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/64
# processing page : 65
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/65
# processing page : 66
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/66
# processing page : 67
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/67
# processing page : 68
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/68
# processing page : 69
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/69
# processing page : 70
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/70
# processing page : 71
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/71
# processing page : 72
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/72
# processing page : 73
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/73
# processing page : 74
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/74
# processing page : 75
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/75
# processing page : 76
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/76
# processing page : 77
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/77
# processing page : 78
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/78
# processing page : 79
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/79
# processing page : 80
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/80
# processing page : 81
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/81
# processing page : 82
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/82
# processing page : 83
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/83
# processing page : 84
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/84
# processing page : 85
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/85
# processing page : 86
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/86
# processing page : 87
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/87
# processing page : 88
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/88
# processing page : 89
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/89
# processing page : 90
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/90
# processing page : 91
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/91
# processing page : 92
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/92
# processing page : 93
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/93
# processing page : 94
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/94
# processing page : 95
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/95
# processing page : 96
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/96
# processing page : 97
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/97
# processing page : 98
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/98
# processing page : 99
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/99
# processing page : 100
# https://www.bbc.com/afrique/topics/cvqxn2k7kv7t/page/100

# %%
data["category"] = "afrique"

# %%
data
# Out:
#                                                  title  \
# 0    José Mourinho, limogé par Tottenham après seul...
# 1    "J'ai placé ma ville natale sur toutes les car...
# 2    Une "cité d'or perdue" vieille de 3 000 ans dé...
# 3    Pourquoi le début du Ramadan diffère d'un pays...
# 4    Comment le CS Chebba s'attaque au patron du fo...
# ..                                                 ...
# 992  Les sud-africains autorisés à acheter de l'alcool
# 993  Indignation au Nigeria après l'assassinat d'un...
# 994  L'Afrique en images : l'art contre le coronavirus
# 995           L'Afrique en image : hommage à DJ Arafat
# 996  Les victimes d’Hissène Habré n'ont toujours pa...
#
#                                              url                 date category
# 0    https://www.bbc.com/afrique/region-52450715                10:29  afrique
# 1    https://www.bbc.com/afrique/region-56764360   9:02 16 avril 2021  afrique
# 2    https://www.bbc.com/afrique/region-56689778  14:56 15 avril 2021  afrique
# 3     https://www.bbc.com/afrique/monde-54526551   9:05 14 avril 2021  afrique
# 4    https://www.bbc.com/afrique/sports-46312814  18:50 13 avril 2021  afrique
# ..                                           ...                  ...      ...
# 992  https://www.bbc.com/afrique/region-52872490     0:10 1 juin 2020  afrique
# 993  https://www.bbc.com/afrique/region-52868506    16:54 31 mai 2020  afrique
# 994  https://www.bbc.com/afrique/region-52868504    13:15 31 mai 2020  afrique
# 995  https://www.bbc.com/afrique/region-49368915    13:11 31 mai 2020  afrique
# 996  https://www.bbc.com/afrique/region-52868502    11:03 31 mai 2020  afrique
#
# [997 rows x 4 columns]

# %%
pagesToGet= 71

data2 = pd.DataFrame([])
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/'+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    links = soup.find_all('li',attrs={"class":"lx-stream__post-container"})
    for i in links:
        try: 
            title = i.find("span",attrs={'class':'lx-stream-post__header-text gs-u-align-middle'}).text.strip()
            link = "https://www.bbc.com"
            link += i.find('a',attrs={"class":"qa-heading-link lx-stream-post__header-link"})["href"]
            date = i.find('div',attrs={"class":"gs-u-display-flex"}).find("span",attrs={"class":"qa-post-auto-meta"}).text
            data2 = data2.append(pd.DataFrame({'title': title, 'url': link,'date' : date}, index=[0]), ignore_index=True)
        except:
            continue
# Out:
# processing page : 1
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/1
# processing page : 2
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/2
# processing page : 3
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/3
# processing page : 4
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/4
# processing page : 5
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/5
# processing page : 6
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/6
# processing page : 7
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/7
# processing page : 8
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/8
# processing page : 9
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/9
# processing page : 10
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/10
# processing page : 11
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/11
# processing page : 12
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/12
# processing page : 13
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/13
# processing page : 14
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/14
# processing page : 15
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/15
# processing page : 16
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/16
# processing page : 17
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/17
# processing page : 18
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/18
# processing page : 19
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/19
# processing page : 20
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/20
# processing page : 21
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/21
# processing page : 22
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/22
# processing page : 23
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/23
# processing page : 24
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/24
# processing page : 25
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/25
# processing page : 26
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/26
# processing page : 27
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/27
# processing page : 28
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/28
# processing page : 29
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/29
# processing page : 30
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/30
# processing page : 31
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/31
# processing page : 32
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/32
# processing page : 33
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/33
# processing page : 34
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/34
# processing page : 35
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/35
# processing page : 36
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/36
# processing page : 37
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/37
# processing page : 38
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/38
# processing page : 39
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/39
# processing page : 40
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/40
# processing page : 41
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/41
# processing page : 42
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/42
# processing page : 43
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/43
# processing page : 44
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/44
# processing page : 45
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/45
# processing page : 46
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/46
# processing page : 47
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/47
# processing page : 48
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/48
# processing page : 49
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/49
# processing page : 50
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/50
# processing page : 51
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/51
# processing page : 52
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/52
# processing page : 53
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/53
# processing page : 54
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/54
# processing page : 55
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/55
# processing page : 56
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/56
# processing page : 57
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/57
# processing page : 58
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/58
# processing page : 59
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/59
# processing page : 60
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/60
# processing page : 61
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/61
# processing page : 62
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/62
# processing page : 63
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/63
# processing page : 64
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/64
# processing page : 65
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/65
# processing page : 66
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/66
# processing page : 67
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/67
# processing page : 68
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/68
# processing page : 69
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/69
# processing page : 70
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/70
# processing page : 71
# https://www.bbc.com/afrique/topics/cvqxn21vx11t/page/71

# %%
data2["category"] = "monde"

# %%
pagesToGet= 26

data3 = pd.DataFrame([])
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.bbc.com/afrique/topics/c404v54yrqyt/page/'+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    links = soup.find_all('li',attrs={"class":"lx-stream__post-container"})
    for i in links:
        try: 
            title = i.find("span",attrs={'class':'lx-stream-post__header-text gs-u-align-middle'}).text.strip()
            link = "https://www.bbc.com"
            link += i.find('a',attrs={"class":"qa-heading-link lx-stream-post__header-link"})["href"]
            date = i.find('div',attrs={"class":"gs-u-display-flex"}).find("span",attrs={"class":"qa-post-auto-meta"}).text
            data3 = data3.append(pd.DataFrame({'title': title, 'url': link,'date' : date}, index=[0]), ignore_index=True)
        except:
            continue
# Out:
# processing page : 1
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/1
# processing page : 2
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/2
# processing page : 3
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/3
# processing page : 4
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/4
# processing page : 5
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/5
# processing page : 6
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/6
# processing page : 7
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/7
# processing page : 8
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/8
# processing page : 9
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/9
# processing page : 10
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/10
# processing page : 11
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/11
# processing page : 12
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/12
# processing page : 13
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/13
# processing page : 14
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/14
# processing page : 15
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/15
# processing page : 16
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/16
# processing page : 17
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/17
# processing page : 18
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/18
# processing page : 19
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/19
# processing page : 20
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/20
# processing page : 21
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/21
# processing page : 22
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/22
# processing page : 23
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/23
# processing page : 24
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/24
# processing page : 25
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/25
# processing page : 26
# https://www.bbc.com/afrique/topics/c404v54yrqyt/page/26

# %%
data3["category"] = "sport"

# %%
pagesToGet= 12

data4 = pd.DataFrame([])
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/'+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    links = soup.find_all('li',attrs={"class":"lx-stream__post-container"})
    for i in links:
        try: 
            title = i.find("span",attrs={'class':'lx-stream-post__header-text gs-u-align-middle'}).text.strip()
            link = "https://www.bbc.com"
            link += i.find('a',attrs={"class":"qa-heading-link lx-stream-post__header-link"})["href"]
            date = i.find('div',attrs={"class":"gs-u-display-flex"}).find("span",attrs={"class":"qa-post-auto-meta"}).text
            data4 = data4.append(pd.DataFrame({'title': title, 'url': link,'date' : date}, index=[0]), ignore_index=True)
        except:
            continue
# Out:
# processing page : 1
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/1
# processing page : 2
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/2
# processing page : 3
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/3
# processing page : 4
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/4
# processing page : 5
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/5
# processing page : 6
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/6
# processing page : 7
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/7
# processing page : 8
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/8
# processing page : 9
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/9
# processing page : 10
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/10
# processing page : 11
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/11
# processing page : 12
# https://www.bbc.com/afrique/topics/cnq687nr9v1t/page/12

# %%
data4["category"] = "Economie"

# %%
pagesToGet= 15

data5 = pd.DataFrame([])
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.bbc.com/afrique/topics/cnq687nn703t/page/'+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    links = soup.find_all('li',attrs={"class":"lx-stream__post-container"})
    for i in links:
        try: 
            title = i.find("span",attrs={'class':'lx-stream-post__header-text gs-u-align-middle'}).text.strip()
            link = "https://www.bbc.com"
            link += i.find('a',attrs={"class":"qa-heading-link lx-stream-post__header-link"})["href"]
            date = i.find('div',attrs={"class":"gs-u-display-flex"}).find("span",attrs={"class":"qa-post-auto-meta"}).text
            data5 = data5.append(pd.DataFrame({'title': title, 'url': link,'date' : date}, index=[0]), ignore_index=True)
        except:
            continue
# Out:
# processing page : 1
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/1
# processing page : 2
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/2
# processing page : 3
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/3
# processing page : 4
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/4
# processing page : 5
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/5
# processing page : 6
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/6
# processing page : 7
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/7
# processing page : 8
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/8
# processing page : 9
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/9
# processing page : 10
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/10
# processing page : 11
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/11
# processing page : 12
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/12
# processing page : 13
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/13
# processing page : 14
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/14
# processing page : 15
# https://www.bbc.com/afrique/topics/cnq687nn703t/page/15

# %%
data5["category"] = "Technologies"

# %%
pagesToGet= 80

data6 = pd.DataFrame([])
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/'+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    links = soup.find_all('li',attrs={"class":"lx-stream__post-container"})
    for i in links:
        try: 
            title = i.find("span",attrs={'class':'lx-stream-post__header-text gs-u-align-middle'}).text.strip()
            link = "https://www.bbc.com"
            link += i.find('a',attrs={"class":"qa-heading-link lx-stream-post__header-link"})["href"]
            date = i.find('div',attrs={"class":"gs-u-display-flex"}).find("span",attrs={"class":"qa-post-auto-meta"}).text
            data6 = data6.append(pd.DataFrame({'title': title, 'url': link,'date' : date}, index=[0]), ignore_index=True)
        except:
            continue
# Out:
# processing page : 1
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/1
# processing page : 2
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/2
# processing page : 3
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/3
# processing page : 4
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/4
# processing page : 5
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/5
# processing page : 6
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/6
# processing page : 7
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/7
# processing page : 8
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/8
# processing page : 9
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/9
# processing page : 10
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/10
# processing page : 11
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/11
# processing page : 12
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/12
# processing page : 13
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/13
# processing page : 14
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/14
# processing page : 15
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/15
# processing page : 16
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/16
# processing page : 17
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/17
# processing page : 18
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/18
# processing page : 19
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/19
# processing page : 20
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/20
# processing page : 21
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/21
# processing page : 22
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/22
# processing page : 23
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/23
# processing page : 24
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/24
# processing page : 25
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/25
# processing page : 26
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/26
# processing page : 27
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/27
# processing page : 28
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/28
# processing page : 29
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/29
# processing page : 30
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/30
# processing page : 31
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/31
# processing page : 32
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/32
# processing page : 33
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/33
# processing page : 34
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/34
# processing page : 35
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/35
# processing page : 36
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/36
# processing page : 37
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/37
# processing page : 38
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/38
# processing page : 39
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/39
# processing page : 40
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/40
# processing page : 41
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/41
# processing page : 42
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/42
# processing page : 43
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/43
# processing page : 44
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/44
# processing page : 45
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/45
# processing page : 46
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/46
# processing page : 47
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/47
# processing page : 48
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/48
# processing page : 49
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/49
# processing page : 50
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/50
# processing page : 51
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/51
# processing page : 52
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/52
# processing page : 53
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/53
# processing page : 54
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/54
# processing page : 55
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/55
# processing page : 56
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/56
# processing page : 57
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/57
# processing page : 58
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/58
# processing page : 59
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/59
# processing page : 60
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/60
# processing page : 61
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/61
# processing page : 62
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/62
# processing page : 63
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/63
# processing page : 64
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/64
# processing page : 65
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/65
# processing page : 66
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/66
# processing page : 67
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/67
# processing page : 68
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/68
# processing page : 69
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/69
# processing page : 70
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/70
# processing page : 71
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/71
# processing page : 72
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/72
# processing page : 73
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/73
# processing page : 74
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/74
# processing page : 75
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/75
# processing page : 76
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/76
# processing page : 77
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/77
# processing page : 78
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/78
# processing page : 79
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/79
# processing page : 80
# https://www.bbc.com/afrique/topics/c06gq9jxz3rt/page/80

# %%
data6["category"] = "Santé"

# %%
data
# Out:
#                                                  title  \
# 0    José Mourinho, limogé par Tottenham après seul...
# 1    "J'ai placé ma ville natale sur toutes les car...
# 2    Une "cité d'or perdue" vieille de 3 000 ans dé...
# 3    Pourquoi le début du Ramadan diffère d'un pays...
# 4    Comment le CS Chebba s'attaque au patron du fo...
# ..                                                 ...
# 992  Les sud-africains autorisés à acheter de l'alcool
# 993  Indignation au Nigeria après l'assassinat d'un...
# 994  L'Afrique en images : l'art contre le coronavirus
# 995           L'Afrique en image : hommage à DJ Arafat
# 996  Les victimes d’Hissène Habré n'ont toujours pa...
#
#                                              url                 date category
# 0    https://www.bbc.com/afrique/region-52450715                10:29  afrique
# 1    https://www.bbc.com/afrique/region-56764360   9:02 16 avril 2021  afrique
# 2    https://www.bbc.com/afrique/region-56689778  14:56 15 avril 2021  afrique
# 3     https://www.bbc.com/afrique/monde-54526551   9:05 14 avril 2021  afrique
# 4    https://www.bbc.com/afrique/sports-46312814  18:50 13 avril 2021  afrique
# ..                                           ...                  ...      ...
# 992  https://www.bbc.com/afrique/region-52872490     0:10 1 juin 2020  afrique
# 993  https://www.bbc.com/afrique/region-52868506    16:54 31 mai 2020  afrique
# 994  https://www.bbc.com/afrique/region-52868504    13:15 31 mai 2020  afrique
# 995  https://www.bbc.com/afrique/region-49368915    13:11 31 mai 2020  afrique
# 996  https://www.bbc.com/afrique/region-52868502    11:03 31 mai 2020  afrique
#
# [997 rows x 4 columns]

# %%
df = data.append(data2, ignore_index=True)

# %%
df= df.append(data3, ignore_index=True)

# %%
df = df.append(data4, ignore_index=True)

# %%
df = df.append(data5, ignore_index=True)

# %%
df = df.append(data6, ignore_index=True)

# %%
df.shape
# Out:
# (3007, 4)

# %%
df = df.drop_duplicates(subset='url')

# %%
df.shape
# Out:
# (2349, 4)

# %%
df.to_csv("bbcafrique.csv",index=False)

# %%
df2 = pd.read_csv("bbcafrique.csv")

# %%
df2.shape
# Out:
# (2349, 4)

# %%
def extract_userneed(x):
    page=requests.get(x)
    soup=BeautifulSoup(page.text,'html.parser')
    for i in soup.findAll("script"):
        try:
            return re.findall(r'(?<="campaignName".").+?(?=\")', str(i.string))[0]
        except:
            continue

# %%
# %%time
df2["User Need"] = df2["url"].apply(lambda x : extract_userneed(x))

# %%
def get_text(url):
    article = requests.get(url)
    soup = BeautifulSoup(article.content, 'html.parser')
    body = soup.find(role='main')
    text = [p.text for p in body.find_all('p',dir="ltr")]
    return ''.join(text)

# %%
# %%time
df2["text"] = df2["url"].apply(lambda x : get_text(x))
# Out:
# CPU times: user 2min 51s, sys: 4.61 s, total: 2min 55s
# Wall time: 21min 53s

# %%
df2["User Need"].value_counts()
# Out:
# WS - Educate me             568
# WS - Give me perspective    497
# WS - Keep me on trend       343
# WS - Update me              343
# WS - Inspire me             327
# WS - CS                     184
# WS - Divert me               58
# News - Disclosure            14
# News - Learning               4
# Educate me                    2
# Give me perspective           1
# News - Reader Revenue         1
# CS                            1
# Name: User Need, dtype: int64

# %%
df2["User Need"] = df2["User Need"].apply(lambda s: re.sub(r"(WS - )", "", s) if pd.notnull(s) else s)

# %%
df2.shape
# Out:
# (2349, 6)

# %%
df2 = df2.dropna(subset=['User Need', 'text'])

# %%
df2.shape
# Out:
# (2343, 6)

# %%
df2["User Need"].value_counts()
# Out:
# Educate me               570
# Give me perspective      498
# Update me                343
# Keep me on trend         343
# Inspire me               327
# CS                       185
# Divert me                 58
# News - Disclosure         14
# News - Learning            4
# News - Reader Revenue      1
# Name: User Need, dtype: int64

# %%
df2.head()
# Out:
#                                                title  \
# 0  José Mourinho, limogé par Tottenham après seul...
# 1  "J'ai placé ma ville natale sur toutes les car...
# 2  Une "cité d'or perdue" vieille de 3 000 ans dé...
# 3  Pourquoi le début du Ramadan diffère d'un pays...
# 4  Comment le CS Chebba s'attaque au patron du fo...
#
#                                            url                 date category  \
# 0  https://www.bbc.com/afrique/region-52450715                10:29  afrique
# 1  https://www.bbc.com/afrique/region-56764360   9:02 16 avril 2021  afrique
# 2  https://www.bbc.com/afrique/region-56689778  14:56 15 avril 2021  afrique
# 3   https://www.bbc.com/afrique/monde-54526551   9:05 14 avril 2021  afrique
# 4  https://www.bbc.com/afrique/sports-46312814  18:50 13 avril 2021  afrique
#
#           User Need                                               text
# 0  Keep me on trend  Le Portugais a remplacé Mauricio Pochettino co...
# 1                CS  Alors qu'il étudiait aux États-Unis, on a dema...
# 2        Educate me  La découverte d'une ville vieille de 3 000 ans...
# 3        Educate me  Les musulmans entament le mois béni du ramadan...
# 4         Update me  La Fédération Tunisienne de Football (FTF) et ...

# %%
df2.to_csv("bbc_afrique_userneeds.csv",index=False)

# %%
test = pd.read_csv("bbc_afrique_userneeds.csv")
test.head()
# Out:
#                                                title  \
# 0  José Mourinho, limogé par Tottenham après seul...
# 1  "J'ai placé ma ville natale sur toutes les car...
# 2  Une "cité d'or perdue" vieille de 3 000 ans dé...
# 3  Pourquoi le début du Ramadan diffère d'un pays...
# 4  Comment le CS Chebba s'attaque au patron du fo...
#
#                                            url                 date category  \
# 0  https://www.bbc.com/afrique/region-52450715                10:29  afrique
# 1  https://www.bbc.com/afrique/region-56764360   9:02 16 avril 2021  afrique
# 2  https://www.bbc.com/afrique/region-56689778  14:56 15 avril 2021  afrique
# 3   https://www.bbc.com/afrique/monde-54526551   9:05 14 avril 2021  afrique
# 4  https://www.bbc.com/afrique/sports-46312814  18:50 13 avril 2021  afrique
#
#           User Need                                               text
# 0  Keep me on trend  Le Portugais a remplacé Mauricio Pochettino co...
# 1                CS  Alors qu'il étudiait aux États-Unis, on a dema...
# 2        Educate me  La découverte d'une ville vieille de 3 000 ans...
# 3        Educate me  Les musulmans entament le mois béni du ramadan...
# 4         Update me  La Fédération Tunisienne de Football (FTF) et ...
